# %%
Q1. Describe the decision tree classifier algorithm and how it works to make predictions.

# %% [markdown]
# #### A decision tree algorithm is a machine learning algorithm that uses a decision tree to make predictions. It follows a tree-like model of decisions and their possible consequences. The algorithm works by recursively splitting the data into subsets based on the most significant feature at each node of the tree.

# %%
Q2. Provide a step-by-step explanation of the mathematical intuition behind decision tree classification.

# %% [markdown]
# #### Entropy or Gini impurity can use to measure the impurity:
#
# -- lower the data set, entropy will be better
#
# --higher the data set, Gini impurity will use

# %%
from IPython import display
display.Image("Entropy.png")

# %%
from IPython import display
display.Image("Gini Impurity.png")

# %% [markdown]
# #### Information Gain will use which feature to select to start the split: feature with Highest information gain will be selected for first split.

# %%
from IPython import display
display.Image("Information Gain.png")

# %%
Q3. Explain how a decision tree classifier can be used to solve a binary classification problem.

# %% [markdown]
# #### A Binary Decision Tree is a structure based on a sequential decision process. Starting from the root, a feature is evaluated and one of the two branches is selected. This procedure is repeated until a final leaf is reached, which normally represents the classification target you're looking for.

# %%
Q4. Discuss the geometric intuition behind decision tree classification and how it can be used to make 
predictions.

# %%
from IPython import display
display.Image("Geomtrical intuition.png")

# %%
Q5. Define the confusion matrix and describe how it can be used to evaluate the performance of a 
classification model.

# %% [markdown]
# #### A Confusion matrix is an N x N matrix used for evaluating the performance of a classification model, where N is the total number of target classes. The matrix compares the actual target values with those predicted by the machine learning model.

# %%
Q6. Provide an example of a confusion matrix and explain how precision, recall, and F1 score can be 
calculated from it.

# %%
from IPython import display
display.Image("ConfusionMatrtix.png")

# %%
display.Image("Accuracy.png")

# %%
display.Image("Precision.png")

# %%
display.Image("Recall.png")

# %%
display.Image("F1_Score.png")

# %% [markdown]
# #### accuracy = 0.96
# #### Precisioon = 0.5
# #### Recall = 0.75
# #### F1-Score = 0.6

# %%
Q7. Discuss the importance of choosing an appropriate evaluation metric for a classification problem and 
explain how this can be done.

# %% [markdown]
# #### We have learned different metrics used to evaluate the classification models. When to use which metrics depends primarily on the nature of your problem. So get back to your model now, question yourself what is the main purpose you are trying to solve, select the right metrics, and evaluate your model.

# %%
Q8. Provide an example of a classification problem where precision is the most important metric, and 
explain why.

# %% [markdown]
# #### Precision is used where False positive is important and need to reduce that vealue.

# %% [markdown]
# --Spam message is an exmaple.
#
# --False positive means where non spam messages predicted as Spam message.
#
# --We need to reduce this FP, So we use Precision.

# %%
Q9. Provide an example of a classification problem where recall is the most important metric, and explain 
why.

# %% [markdown]
# #### Precision is used where False Negaitive is important and need to reduce that vealue.

# %% [markdown]
# --Diabetis is an exmaple.
#
# --False Negative means, where Diabetis patients categirized as non dia-betis and they wont go for re-test.
#
# --We need to reduce this FN, So we use Recall.
